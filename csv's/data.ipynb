# %%
import pandas as pd

# %%
df = pd.read_csv('/mnt/data1/srini/ai_evalsv4/csv\'s/query_result_2025-11-14T13_52_48.293337128Z.csv')
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (14,68,69,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns
# Out:
# Index(['Show ID', 'Image URL', 'Saved By', 'Prompt', 'ID', 'Negative Prompt',
#        'Batch Count', 'Cfg Scale', 'Steps', 'Seed', 'Image Width',
#        'Image Height', 'Style', 'Sub Style', 'Character', 'Control Net',
#        'Is Favourite', 'Created At', 'Control Net Details', 'Generation ID',
#        'Rating', 'Metadata', 'Frame ID', 'State', 'Type', 'Character Weight',
#        'Style Weight', 'Denoise Strength', 'Episode ID', 'Token Merging Ratio',
#        'IP Adapter', 'Photomaker Details', 'Datastream Metadata', 'Tenant',
#        'Inference - Generation → ID', 'Inference - Generation → Image URL',
#        'Inference - Generation → Prompt', 'Inference - Generation → Metadata',
#        'Inference - Generation → Created At',
#        'Inference - Generation → Updated At',
#        'Inference - Generation → Init Image',
#        'Inference - Generation → Mask Image',
#        'Inference - Generation → Negative Prompt',
# ...

# %%
df.head(1)
# Out:
#                Show ID                                          Image URL  \
# 0  SHOcUGMvK4kngv2C3AG  https://content.dashtoon.ai/stability-images/9...
#
#               Saved By                                             Prompt  \
# 0  aaliya@dashverse.ai  Transfer the dress from the second image to th...
#
#          ID Negative Prompt  Batch Count  Cfg Scale  Steps         Seed  ...  \
# 0  73103640             NaN            4        4.5     50  982,722,317  ...
#
#   Inference - Generation → Token Merging Ratio  \
# 0                                            0
#
#   Inference - Generation → Generation Time Estimate  \
# 0                                               123
#
#   Inference - Generation → Actual Generation Time  \
# 0                                             104
#
#   Inference - Generation → Upload Time Inference - Generation → IP Adapter  \
# 0                                  0.0                                  []
#
# ...

# %%
print(df.loc[28, 'Image URL'])
# Out:
# https://content.dashtoon.ai/stability-images/0e461faa-f9b1-4352-acb6-801fe077a5d8.png
